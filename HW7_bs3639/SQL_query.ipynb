# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the same account you used in the lab (hvt201)  and query the database that you were querying in class (citibike_feb_2015)

# %%
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd
from IPython.display import display as D

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %% [markdown]
# ## Test

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(test = '''
SELECT *
FROM citibike
''')), sep=',').head()
# Out:
#    cartodb_id  the_geom  the_geom_webmercator  tripduration      starttime  \
# 0           1       NaN                   NaN           801  2/1/2015 0:00
# 1          89       NaN                   NaN           245  2/1/2015 1:03
# 2           2       NaN                   NaN           379  2/1/2015 0:00
# 3           3       NaN                   NaN          2474  2/1/2015 0:01
# 4           4       NaN                   NaN           818  2/1/2015 0:01
#
#         stoptime  start_station_id                 start_station_name  \
# 0  2/1/2015 0:14               521                    8 Ave & W 31 St
# 1  2/1/2015 1:07               438                St Marks Pl & 1 Ave
# 2  2/1/2015 0:07               497                 E 17 St & Broadway
# 3  2/1/2015 0:42               281  Grand Army Plaza & Central Park S
# 4  2/1/2015 0:15              2004                  6 Ave & Broome St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %% [markdown]
# ## Task 1

# %%
print('Sorted by start_station_id and tripduration where tripduration > 3 hours')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT *
FROM citibike
WHERE tripduration > 180
ORDER BY start_station_id, tripduration
''')), sep=',')

df.head()
# Out:
# Sorted by start_station_id and tripduration where tripduration > 3 hours
#    cartodb_id  the_geom  the_geom_webmercator  tripduration      starttime  \
# 0          75       NaN                   NaN           511  2/1/2015 0:50
# 1         165       NaN                   NaN           224  2/1/2015 2:28
# 2         142       NaN                   NaN           428  2/1/2015 1:54
# 3         166       NaN                   NaN           521  2/1/2015 2:29
# 4          92       NaN                   NaN           731  2/1/2015 1:11
#
#         stoptime  start_station_id        start_station_name  \
# 0  2/1/2015 0:59               119  Park Ave & St Edwards St
# 1  2/1/2015 2:32               128  MacDougal St & Prince St
# 2  2/1/2015 2:02               128  MacDougal St & Prince St
# 3  2/1/2015 2:38               128  MacDougal St & Prince St
# 4  2/1/2015 1:23               128  MacDougal St & Prince St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
print('Head')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT *
FROM citibike
ORDER BY tripduration
LIMIT 5
''')), sep=',')

df
# Out:
# Head
#    cartodb_id  the_geom  the_geom_webmercator  tripduration      starttime  \
# 0          82       NaN                   NaN            89  2/1/2015 0:53
# 1         114       NaN                   NaN           114  2/1/2015 1:30
# 2          28       NaN                   NaN           144  2/1/2015 0:18
# 3         186       NaN                   NaN           145  2/1/2015 3:23
# 4         191       NaN                   NaN           148  2/1/2015 3:29
#
#         stoptime  start_station_id     start_station_name  \
# 0  2/1/2015 0:55               195  Liberty St & Broadway
# 1  2/1/2015 1:32               486     Broadway & W 29 St
# 2  2/1/2015 0:21               350  Clinton St & Grand St
# 3  2/1/2015 3:25               491   E 24 St & Park Ave S
# 4  2/1/2015 3:32               472     E 32 St & Park Ave
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               40.709056               -74.010434             264
# ...

# %%
print('Tail')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT *
FROM citibike
ORDER BY tripduration DESC
LIMIT 5
''')), sep=',')

df
# Out:
# Tail
#    cartodb_id  the_geom  the_geom_webmercator  tripduration      starttime  \
# 0          78       NaN                   NaN         35251  2/1/2015 0:52
# 1          85       NaN                   NaN          2812  2/1/2015 0:55
# 2           3       NaN                   NaN          2474  2/1/2015 0:01
# 3         170       NaN                   NaN          1859  2/1/2015 2:41
# 4         144       NaN                   NaN          1790  2/1/2015 1:57
#
#          stoptime  start_station_id                 start_station_name  \
# 0  2/1/2015 10:40               453                    W 22 St & 8 Ave
# 1   2/1/2015 1:42               401            Allen St & Rivington St
# 2   2/1/2015 0:42               281  Grand Army Plaza & Central Park S
# 3   2/1/2015 3:12               293              Lafayette St & E 8 St
# 4   2/1/2015 2:27               336        Sullivan St & Washington Sq
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
print('unique start_station_id values')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT DISTINCT start_station_id
FROM citibike
ORDER BY start_station_id
''')), sep=',')

df['start_station_id'].values
# Out:
# unique start_station_id values
# array([ 119,  128,  150,  151,  157,  161,  164,  168,  173,  195,  212,
#         223,  228,  236,  237,  238,  243,  250,  254,  267,  271,  274,
#         276,  279,  281,  284,  285,  290,  291,  293,  300,  312,  317,
#         323,  324,  325,  326,  327,  328,  334,  335,  336,  345,  348,
#         350,  352,  368,  373,  382,  383,  393,  394,  401,  403,  404,
#         405,  411,  417,  428,  432,  433,  434,  435,  437,  438,  439,
#         444,  445,  447,  449,  453,  461,  465,  472,  477,  478,  479,
#         482,  483,  485,  486,  487,  489,  490,  491,  493,  497,  498,
#         499,  501,  503,  504,  505,  507,  511,  513,  515,  520,  521,
#         528,  531,  537,  539, 2002, 2004, 2021, 2022])

# %%
print('Count number of trips')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT COUNT(start_station_id)
FROM citibike
''')), sep=',')

df['count'][0]
# Out:
# Count number of trips
# 199

# %%
print('Max/min/avg trip duration')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT MIN(tripduration), MAX(tripduration), AVG(tripduration)
FROM citibike
''')), sep=',')

df
# Out:
# Max/min/avg trip duration
#    min    max         avg
# 0   89  35251  775.527638

# %% [markdown]
# ## Task 2

# %%
print('Selecting trips started on Feb-02-2015 only')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT *
FROM citibike
WHERE starttime >= '2015-02-02 00:00'
AND   starttime <  '2015-02-03 00:00'
''')), sep=',')

df.head()
# Out:
# Selecting trips started on Feb-02-2015 only
# Empty DataFrame
# Columns: [cartodb_id, the_geom, the_geom_webmercator, tripduration, starttime, stoptime, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude, end_station_longitude, bikeid, usertype, birth_year, gender]
# Index: []

# %%
print('Selecting trips started on the weekends')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT *
FROM citibike
WHERE extract(DOW FROM starttime) IN (5,6)
''')), sep=',')

df.head()
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# Selecting trips started on the weekends
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-8aef6387e7b4> in <module>()
#       4 FROM citibike
#       5 WHERE extract(DOW FROM starttime) IN (5,6)
# ----> 6 ''')), sep=',')
#       7
#       8 df.head()
#
# <ipython-input-1-d34674476fc3> in queryCartoDB(query, format, source)
#      23         response = urllib2.urlopen(source, data)
#      24     except urllib2.HTTPError, e:
# ---> 25         raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
#      26     except Exception:
#      27         raise
#
# ValueError: function pg_catalog.date_part(unknown, text) does not exist

# %%
print('What are average trip duration during weekends?')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT AVG(tripduration)
FROM citibike
WHERE extract(DOW FROM starttime) IN (5,6)
''')), sep=',')

df['avg'][0]
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# What are average trip duration during weekends?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-fbb9535ca515> in <module>()
#       4 FROM citibike
#       5 WHERE extract(DOW FROM starttime) IN (5,6)
# ----> 6 ''')), sep=',')
#       7
#       8 df['avg'][0]
#
# <ipython-input-1-d34674476fc3> in queryCartoDB(query, format, source)
#      23         response = urllib2.urlopen(source, data)
#      24     except urllib2.HTTPError, e:
# ---> 25         raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
#      26     except Exception:
#      27         raise
#
# ValueError: function pg_catalog.date_part(unknown, text) does not exist

# %%
print('Selecting trips started on the week')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT *
FROM citibike
WHERE extract(DOW FROM starttime) NOT IN (5,6)
''')), sep=',')

df.head()
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# Selecting trips started on the week
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-7fa0d1ed767f> in <module>()
#       4 FROM citibike
#       5 WHERE extract(DOW FROM starttime) NOT IN (5,6)
# ----> 6 ''')), sep=',')
#       7
#       8 df.head()
#
# <ipython-input-1-d34674476fc3> in queryCartoDB(query, format, source)
#      23         response = urllib2.urlopen(source, data)
#      24     except urllib2.HTTPError, e:
# ---> 25         raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
#      26     except Exception:
#      27         raise
#
# ValueError: function pg_catalog.date_part(unknown, text) does not exist

# %%
print('What are average trip duration during week?')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT AVG(tripduration)
FROM citibike
WHERE extract(DOW FROM starttime) IN (5,6)
''')), sep=',')

df['avg'][0]
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# What are average trip duration during week?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-9dce222b9242> in <module>()
#       4 FROM citibike
#       5 WHERE extract(DOW FROM starttime) IN (5,6)
# ----> 6 ''')), sep=',')
#       7
#       8 df['avg'][0]
#
# <ipython-input-1-d34674476fc3> in queryCartoDB(query, format, source)
#      23         response = urllib2.urlopen(source, data)
#      24     except urllib2.HTTPError, e:
# ---> 25         raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
#      26     except Exception:
#      27         raise
#
# ValueError: function pg_catalog.date_part(unknown, text) does not exist

# %% [markdown]
# ## Task 3

# %%
print('Showing the list of start station locations')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT
    CDB_transformToWebmercator(CDB_LatLng(
        start_station_latitude,
        start_station_longitude
    )) as the_geom_webmercator,
    MIN(cartodb_id) as cartodb_id
    
FROM citibike
GROUP BY start_station_latitude, start_station_longitude
''')), sep=',')

df.head()
# Out:
# Showing the list of start station locations
#                                 the_geom_webmercator  cartodb_id
# 0  0101000020110F0000309ECD0FB7695FC14F41EB09FDFC...           3
# 1  0101000020110F000059CCF6FF3A6B5FC15A3E50FC0FFB...         156
# 2  0101000020110F000013F98D3C826B5FC1A5B89D5BC9F7...          36
# 3  0101000020110F0000EC774642E56C5FC13DF29213A3F7...          26
# 4  0101000020110F000049C345A6266A5FC17E86BFF6F6F7...          69

# %%
print('Showing the number of trips started per station')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT
    CDB_transformToWebmercator(CDB_LatLng(
        start_station_latitude,
        start_station_longitude
    )) as the_geom_webmercator,
    MIN(cartodb_id) as cartodb_id,
    COUNT(tripduration) as n_trips
    
FROM citibike
GROUP BY start_station_id, start_station_latitude, start_station_longitude
''')), sep=',')

df.head()
# Out:
# Showing the number of trips started per station
#                                 the_geom_webmercator  cartodb_id  n_trips
# 0  0101000020110F0000993A68067B6C5FC1B222DA492BFA...          78        3
# 1  0101000020110F0000164B2764466C5FC1423FA877D4F9...          73        1
# 2  0101000020110F0000A2C21415B46B5FC1BD351D6EC2F8...         172        1
# 3  0101000020110F00009F5AD0F883695FC18BD6351F95FB...          22        1
# 4  0101000020110F0000B491DA452F6A5FC140D0756F30F3...          75        1

# %%
print('but only for stations within 500m of Time Square!')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT
    CDB_transformToWebmercator(CDB_LatLng(
        start_station_latitude,
        start_station_longitude
    )) as the_geom_webmercator,
    MIN(cartodb_id) as cartodb_id,
    COUNT(tripduration) as n_trips
FROM citibike

WHERE ST_DWithin(CDB_LatLng(
          start_station_latitude,
          start_station_longitude
      )::geography,
      CDB_LatLng(40.7577,-73.9857)::geography,500)
GROUP BY start_station_id, start_station_latitude, start_station_longitude
''')), sep=',')

df.head()
# Out:
# but only for stations within 500m of Time Square!
#                                 the_geom_webmercator  cartodb_id  n_trips
# 0  0101000020110F000020D6742CE16A5FC112F4D73D73FC...          42        2
# 1  0101000020110F000004AF971C1D6B5FC17A48F3C1A8FB...          54        1
# 2  0101000020110F0000F55695027D6B5FC186E5BB69D7FB...          33        3
# 3  0101000020110F00009BB87D02B76A5FC146C144E9E5FB...          19        1
# 4  0101000020110F00001607D538556B5FC119A6CA6F41FC...         124        1

# %% [markdown]
# ## Task 4

# %%
print('Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare!')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT
    CDB_transformToWebmercator(CDB_LatLng(
        start_station_latitude,
        start_station_longitude
    )) as the_geom_webmercator,
    MIN(cartodb_id) as cartodb_id,
    COUNT(tripduration) as n_trips,
    AVG(tripduration) as avg_duration
FROM citibike

WHERE 
    EXTRACT(WEEK FROM starttime) IN (0,6)
    AND
    ST_DWithin(CDB_LatLng(
          start_station_latitude,
          start_station_longitude
      )::geography,
      CDB_LatLng(40.7577,-73.9857)::geography,500)
      
GROUP BY start_station_id, start_station_latitude, start_station_longitude
ORDER BY avg_duration DESC
LIMIT 1
''')), sep=',')

df.head()
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-e20068fa72bf> in <module>()
#      23 ORDER BY avg_duration DESC
#      24 LIMIT 1
# ---> 25 ''')), sep=',')
#      26
#      27 df.head()
#
# <ipython-input-1-d34674476fc3> in queryCartoDB(query, format, source)
#      23         response = urllib2.urlopen(source, data)
#      24     except urllib2.HTTPError, e:
# ---> 25         raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
#      26     except Exception:
#      27         raise
#
# ValueError: function pg_catalog.date_part(unknown, text) does not exist

# %%
print('''Extra: create lines for trips started from stations within 500m of Times
Squares and lasted less than 2 hours. The number of trips per each
pair of stations are output as attributes of these lines. ''')
df = pd.read_csv(StringIO.StringIO(queryCartoDB('''
SELECT
    start_station_id,
    end_station_id,
    ST_Makeline(
        CDB_TransformToWebmercator(CDB_LatLng(
            start_station_latitude,
            start_station_longitude)),
        CDB_TransformToWebmercator(CDB_LatLng(
            end_station_latitude,
            end_station_longitude))
    ) as the_geom_webmercator,
    MIN(cartodb_id) as cartodb_id,
    AVG(tripduration) AS avg_duration
FROM citibike
WHERE
    ST_DWithin(
        CDB_LatLng(
            start_station_latitude,
            start_station_longitude)::geography,
        CDB_LatLng(40.7577,-73.9857)::geography, 500)
    AND tripduration < 7200
        
GROUP BY
    start_station_id, start_station_latitude, start_station_longitude,
    end_station_id, end_station_latitude, end_station_longitude
''')), sep=',')

df.head()
# Out:
# Extra: create lines for trips started from stations within 500m of Times
# Squares and lasted less than 2 hours. The number of trips per each
# pair of stations are output as attributes of these lines.
#    start_station_id  end_station_id  \
# 0               173             305
# 1               173             442
# 2               465             174
# 3               477             160
# 4               477             513
#
#                                 the_geom_webmercator  cartodb_id  avg_duration
# 0  0102000020110F00000200000020D6742CE16A5FC112F4...          76         489.0
# 1  0102000020110F00000200000020D6742CE16A5FC112F4...          42         505.0
# 2  0102000020110F00000200000004AF971C1D6B5FC17A48...          54         748.0
# 3  0102000020110F000002000000F55695027D6B5FC186E5...         182         469.0
# 4  0102000020110F000002000000F55695027D6B5FC186E5...          33         559.0

# %% [markdown]
# # extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel

# %%
from future.standard_library import install_aliases
install_aliases()

from urllib.parse import urlencode
from urllib.request import urlopen
from urllib.error import HTTPError

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urlencode({'format': format, 'q': query})
    try:
        response = urlopen(source, data)
    except HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()
